# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
matplotlib.__version__
# Out:
# '3.8.0'

# %%
# %matplotlib inline

# %% [markdown]
# # Importing Data

# %%
path = r'C:\Users\david\Desktop\Achievement 6'

# %%
df = pd.read_csv(os.path.join(path, 'Original Data', 'kc_house_data.csv'))

# %% [markdown]
# # Selecting columns that answer the business questions

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df_dropped = df.drop(columns=['id', 'date', 'sqft_living15', 'sqft_lot15', 'view'])

# %% [markdown]
# # Correlations

# %%
df_dropped.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# sqft_basement  0.323816  0.303093   0.283770     0.435043  0.015286 -0.245705
# ...

# %%
plt.matshow(df_dropped.corr())
plt.show()
plt.savefig("out.png")

# %%
# Add labels, a legend, and change the size of the heatmap

f = plt.figure(figsize=(12, 12)) # figure size 
plt.matshow(df_dropped.corr(), fignum=f.number) # type of plot
plt.xticks(range(df_dropped.shape[1]), df_dropped.columns, fontsize=10, rotation=45) # x axis labels
plt.yticks(range(df_dropped.shape[1]), df_dropped.columns, fontsize=14) # y axis labels
cb = plt.colorbar() # add a colour legend (called colorbar)
cb.ax.tick_params(labelsize=14) # add font size
plt.title('Correlation Matrix', fontsize=14) # add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
f.savefig('test.png')

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))
corr_matrix = df_dropped.corr()
# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(corr_matrix, annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# The following are the variables that have a strong positive correlation with price.
# - bathrooms
# - bedrooms
# - grade
# - sqft_living
# - sqft_above

# %% [markdown]
# # Scatterplots of interesting variables

# %%
f = sns.lmplot(x = 'bedrooms', y = 'price', data = df)

# %%
f.savefig('test3.png')

# %%
f = sns.lmplot(x = 'bathrooms', y = 'price', data = df)

# %%
f.savefig('test2.png')

# %%
f = sns.lmplot(x = 'grade', y = 'price', data = df)

# %%
f.savefig('test4')

# %%
sns.lmplot(x = 'waterfront', y = 'price', data = df)

# %%
sns.lmplot(x = 'sqft_living', y = 'price', data = df)

# %%
sns.lmplot(x = 'sqft_above', y = 'price', data = df)

# %% [markdown]
# Summary: There is a strong positive correlation between all of these variables. An increase in the independent variable leads to an increase in the dependent (price)

# %% [markdown]
# # Pair Plot

# %%
paired_plot = df_dropped[['price', 'bedrooms', 'bathrooms']]

# %%
paired_plot2 = df_dropped[['price', 'sqft_above', 'sqft_living', 'grade', 'waterfront']]

# %%
sns.pairplot(paired_plot)
# Out:
# C:\Users\david\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\david\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\david\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(paired_plot2)
# Out:
# C:\Users\david\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\david\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\david\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# #

# %% [markdown]
# Again, there is a strong positive corrlelation between these variables and price. A significant varaible is the number of bedrooms. This is one of the steepest lines I see.

# %% [markdown]
# # Categorical Plot

# %%
sns.histplot(df['bathrooms'], bins = 20, kde = True)
# Out:
# C:\Users\david\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bathrooms', ylabel='Count'>

# %%
df.loc[df['bathrooms'] <= 1, 'bathroom_size'] = 'Few'

# %%
df.loc[(df['bathrooms'] > 1) & (df['bathrooms'] < 3), 'bathroom_size'] = 'Normal'

# %%
df.loc[df['bathrooms'] >= 3, 'bathroom_size'] = 'Many'

# %%
df['bathroom_size'].value_counts(dropna = False)
# Out:
# bathroom_size
# Normal    15045
# Few        3938
# Many       2630
# Name: count, dtype: int64

# %%
sns.set(style="ticks")
g = sns.catplot(x="bathrooms", y="price", hue="bathroom_size", data=df, height = 6, aspect = 1.5)
# Out:
# C:\Users\david\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# C:\Users\david\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %% [markdown]
# Coloring by the number of bathrooms, the most expensive houses tend to have many bathrooms. The cheapest tend to have few.

# %% [markdown]
# Revised Questions:
# Waterfront property does not seem to be strongly correlated to price. This may not be worth pursuing.

# %% [markdown]
# Hypotheses:
# 1. Homes with more bathrooms have higher prices
# 2. Homes with more bedrooms have higher prices.
# 3. Larger homes have higher prices
# 4. Homes that are graded more favorably have higher prices.
